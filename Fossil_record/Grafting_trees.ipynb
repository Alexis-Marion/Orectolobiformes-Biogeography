# %% [markdown]
# # Grafting posterior tree distribution

# %% [markdown]
# ## Data preparation

# %% [markdown]
# ### Loading packages

# %%
library("TreeTools")
library("phytools")
library("stringr")
library("dispRity")
# Out:
# Le chargement a nécessité le package : ape
#
# Le chargement a nécessité le package : maps
#
#
# Attachement du package : ‘phytools’
#
#
# L'objet suivant est masqué depuis ‘package:TreeTools’:
#
#     as.multiPhylo

# %% [markdown]
# ### Loading data and useful functions

# %%
source("function_grafting.r")

# %%
tree_multi<-read.tree("../Data_orectolobiformes/posterior_distribution_100_tree_orecto.tree")

# %%
phy<-read.tree("../Data_orectolobiformes/tree_orecto.tree")

# %%
fossil_data<-read.table("TS_TE_SP_replicated.tsv", header = TRUE, sep ="\t")

# %%
unique(fossil_data$Family)
# Out:
# [1] "Hemiscylliidae"                "Orectolobiformes_incert._fam."
# [3] "Brachaeluridae"                "Ginglymostomatidae"
# [5] "Orectolobidae"                 "Mesiteiidae"
# [7] "Rhincodontidae"                "Parascylliidae"
# [9] "Stegostomatidae"

# %%
make_random_fossil_extract <- function(fossil_data, phy){
    
}

# %%
fossil_data[fossil_data$Family == "Hemiscylliidae",]
# Out:
#     Order            Family         Genus
# 1   Orectolobiformes Hemiscylliidae Acanthoscyllium
# 2   Orectolobiformes Hemiscylliidae Adnetoscyllium
# 3   Orectolobiformes Hemiscylliidae Almascyllium
# 25  Orectolobiformes Hemiscylliidae Chiloscyllium
# 26  Orectolobiformes Hemiscylliidae Chiloscyllium
# 27  Orectolobiformes Hemiscylliidae Chiloscyllium
# 28  Orectolobiformes Hemiscylliidae Chiloscyllium
# 29  Orectolobiformes Hemiscylliidae Chiloscyllium
# 30  Orectolobiformes Hemiscylliidae Chiloscyllium
# 31  Orectolobiformes Hemiscylliidae Chiloscyllium
# 32  Orectolobiformes Hemiscylliidae Chiloscyllium
# 33  Orectolobiformes Hemiscylliidae Chiloscyllium
# 34  Orectolobiformes Hemiscylliidae Chiloscyllium
# 35  Orectolobiformes Hemiscylliidae Chiloscyllium
# 36  Orectolobiformes Hemiscylliidae Chiloscyllium
# 37  Orectolobiformes Hemiscylliidae Coelometlaouia
# 67  Orectolobiformes Hemiscylliidae Hemiscyllium
# 68  Orectolobiformes Hemiscylliidae Hemiscyllium
# 69  Orectolobiformes Hemiscylliidae Hemiscyllium
# 77  Orectolobiformes Hemiscylliidae Notoramphoscyllium
# 119 Orectolobiformes Hemiscylliidae Pseudospinax
# 120 Orectolobiformes Hemiscylliidae Pseudospinax
#     Species                        Ts        Te       Ts_sd     Te_sd
# 1   Acanthoscyllium_sahelalmae      85.37120 83.90468 0.6674255 0.7014267
# 2   Adnetoscyllium_angloparisensis  86.25006 80.21402 0.6675094 0.2980131
# 3   Almascyllium_cheikheliasi       85.36657 83.92354 0.6303540 0.6051588
# 25  Chiloscyllium_broennimanni      69.47201 67.75976 2.2957912 2.0060461
# 26  Chiloscyllium_frequens          86.29027 72.76848 0.4605543 1.1605614
# 27  Chiloscyllium_gaemersi          74.89527 72.88216 1.3857921 1.5105151
# 123 Rhincodon_ferriolensis                20.30286  15.48995 0.8205900
# 124 Rhincodon_typus                       33.04987   0.00000 6.2303852
# 125 Squatiscyllium_casieri                52.84596  50.89581 1.9750968
# 126 Squatiscyllium_nigeriensis            59.17387  51.74622 0.5344202
# 127 Stegostoma_tethysiensis               40.59213  38.77285 1.3828666
#     Te_sd
# 1   0.7014267
# 2   0.2980131
# 3   0.6051588
# 4   1.4609423
# 5   0.6223649
# 6   2.4723321
# 7   0.9581897
# 8   1.1913003
# 9   1.1886283
# 10  1.2779080
# 11  1.2614764
# 12  3.3053163
# 13  0.8278541
# 14  0.7582171
# 15  0.5633992
# 16  1.4141247
# 17  2.0136924
# 18  1.1245520
# 19  1.8183560
# 20  1.5396034
# 21  0.7892322
# 22  0.5096808
# 23  1.2024209
# 24  0.5529079
# 25  2.0060461
# 26  1.1605614
# 27  1.5105151
# 28  0.6263321
# 29  0.4778819
# 30  1.1891869
# ⋮   ⋮
# 98  2.5741803
# 99  1.1356733
# 100 1.5679246
# 101 1.1976154
# 102 1.2298158
# 103 0.7730940
# 104 0.7872967
# 105 1.2238262
# 106 0.3816539
# 107 1.5359188
# 108 2.0163549
# 109 0.8194115
# 110 0.7919219
# 111 0.6148981
# 112 0.5172142
# 113 0.4278633
# 114 0.5572713
# 115 0.4230120
# 116 0.9368766
# 117 0.5333698
# 118 0.9627395
# 119 1.3185636
# 120 2.0645466
# 121 0.5245405
# 122 1.0849179
# 123 1.5562150
# 124 0.0000000
# 125 2.6226426
# 126 3.4338390
# 127 0.5867023

# %% [markdown]
# ## Grafting 1,000 replicates for the consensus tree

# %%
multi_tree<-function(tree, fossil_data, taxonomy, output){
phylo_list<-list()
class(phylo_list)<-"multiPhylo"
       for(i in 1:1000){
           
            temp_tree<-tree
           
            taxo_eoetmopterus_supracretaceus<-extract.clade(temp_tree, getMRCA(temp_tree, c("Etmopterus_sheikoi", "Aculeola_nigra")))$tip.label
            temp_tree<-tree_grafting_manual(temp_tree, fossil_data, "Eoetmopterus_supracretaceus", taxo_eoetmopterus_supracretaceus, 1)

            phylo_list[[i]]<-temp_tree
       }
    write.nexus(phylo_list, file = output)
}

# %% [markdown]
# ## Saving the multi tree filem

# %%
multi_tree(phy, fossil_data, table_trait, "../../raw_data/Multi_Squaliformes_fossil_consensus_distribution.tree")

# %% [markdown]
# ## Grafting fossils on the posterior tree distribution

# %%
multi_tree_posterior<-function(tree, fossil_data, taxonomy, output){
phylo_list<-list()
class(phylo_list)<-"multiPhylo"
       for(i in 1:100){
           
            temp_tree<-extract.clade(tree[[i]], getMRCA(tree[[i]], c("Squalus_acanthias", "Etmopterus_princeps")))

            taxo_eoetmopterus_supracretaceus<-extract.clade(temp_tree, getMRCA(temp_tree, c("Etmopterus_sheikoi", "Aculeola_nigra")))$tip.label
            temp_tree<-tree_grafting_manual(temp_tree, fossil_data, "Eoetmopterus_supracretaceus", taxo_eoetmopterus_supracretaceus, 1)

            taxo_isistius_trituratus<-c("Isistius_brasiliensis")
            temp_tree<-tree_grafting_manual(temp_tree, fossil_data, "Isistius_trituratus", taxo_isistius_trituratus, 1)
           
            taxo_protocentrophorus_balticus<-extract.clade(temp_tree, getMRCA(temp_tree, c("Deania_calcea", "Centrophorus_squamosus", "Centrophorus_granulosus")))$tip.label
            temp_tree<-tree_grafting_manual(temp_tree, fossil_data, "Protocentrophorus_balticus", taxo_protocentrophorus_balticus, 1)
            
            taxo_protosqualus_albertsi<-extract.clade(temp_tree, getMRCA(temp_tree, c("Squalus_acanthias", "Cirrhigaleus_barbifer", "Squalus_cubensis")))$tip.label
            temp_tree<-tree_grafting_manual(temp_tree, fossil_data, "Protosqualus_albertsi", taxo_protosqualus_albertsi, 1)

            taxo_protosqualus_sigei<-extract.clade(temp_tree, getMRCA(temp_tree, c("Squalus_acanthias", "Cirrhigaleus_barbifer", "Squalus_cubensis")))$tip.label
            temp_tree<-tree_grafting_manual(temp_tree, fossil_data, "Protosqualus_sigei", taxo_protosqualus_sigei, 1)

            taxo_squalus_minor<-extract.clade(temp_tree, getMRCA(temp_tree, c("Squalus_acanthias", "Cirrhigaleus_barbifer", "Squalus_cubensis")))$tip.label
            temp_tree<-tree_grafting_manual(temp_tree, fossil_data, "Squalus_minor", taxo_squalus_minor, 1)

            taxo_trigonognathus_virginiae<-c("Trigonognathus_kabeyai")
            temp_tree<-tree_grafting_manual(temp_tree, fossil_data, "Trigonognathus_virginiae", taxo_trigonognathus_virginiae, 1)

            taxo_eodalatias_crenulatus<-c("Dalatias_licha")
            temp_tree<-tree_grafting_manual(temp_tree, fossil_data, "Eodalatias_crenulatus", taxo_eodalatias_crenulatus, 1)

            taxo_squalidalatias_savoiei<-extract.clade(temp_tree, getMRCA(temp_tree, c("Dalatias_licha", "Isistius_brasiliensis")))$tip.label
            temp_tree<-tree_grafting_manual(temp_tree, fossil_data, "Squaliodalatias_savoiei", taxo_squalidalatias_savoiei, 1)

            taxo_proetmopterus_hemmooriensis<-extract.clade(temp_tree, getMRCA(temp_tree, c("Etmopterus_sheikoi", "Etmopterus_princeps", "Etmopterus_polli")))$tip.label
            temp_tree<-tree_grafting_manual(temp_tree, fossil_data, "Proetmopterus_hemmooriensis", taxo_proetmopterus_hemmooriensis, 1)

            taxo_cretascymnus_westfalicus<-extract.clade(temp_tree, getMRCA(temp_tree, c("Somniosus_microcephalus", "Rhinoscymnus_rostratus")))$tip.label
            temp_tree<-tree_grafting_manual(temp_tree, fossil_data, "Cretascymnus_westfalicus", taxo_cretascymnus_westfalicus, 1)

            taxo_cretascymnus_adonis<-extract.clade(temp_tree, getMRCA(temp_tree, c("Somniosus_microcephalus", "Rhinoscymnus_rostratus")))$tip.label
            temp_tree<-tree_grafting_manual(temp_tree, fossil_data, "Cretascymnus_adonis", taxo_cretascymnus_adonis, 1)
            phylo_list[[i]]<-temp_tree
       }
    write.tree(phylo_list, file = output)
}

# %% [markdown]
# ## Saving the 100 grafted trees

# %%
multi_tree_posterior(tree, fossil_data, table_trait, "../../raw_data/Multi_Squaliformes_fossil_posterior_distribution.tree")
