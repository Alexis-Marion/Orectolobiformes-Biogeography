# %% [markdown]
# # Combining extant data and extinct data for PyRate and DES

# %% [markdown]
# ## Loading packages

# %%
library("SpeciesAge")
library("ape")
# Out:
# Le chargement a nécessité le package : ape
#
# Le chargement a nécessité le package : diversitree
#
# Le chargement a nécessité le package : TreeSim
#
# Le chargement a nécessité le package : geiger
#
# Le chargement a nécessité le package : phytools
#
# Le chargement a nécessité le package : maps
#
# Le chargement a nécessité le package : picante
#
# Le chargement a nécessité le package : vegan
#
# Le chargement a nécessité le package : permute
#
# Le chargement a nécessité le package : lattice
#
# This is vegan 2.6-8
#
#
# Attachement du package : ‘vegan’
#
#
# L'objet suivant est masqué depuis ‘package:phytools’:
#
#     scores
#
#
# Le chargement a nécessité le package : nlme

# %% [markdown]
# ## Loading data

# %%
tree_list <- read.tree("../Data_orectolobiformes/posterior_distribution_100_tree_orecto.tree")

# %%
tabl <- read.table("Data/Data_Occ_sp_Orecto_TaxonList.txt", sep ="\t", header = TRUE)

# %%
lst_files_TS_TE <- list.files("PyRate/Species_combined/TS_TE/", full.names = TRUE)

# %%
lst_files_DES <- list.files("../DES/Analysis_ML/sp_1/", full.names = TRUE)

# %%
tab <- read.csv("PyRate/Rates_sp.csv", header = FALSE, sep =";")

# %% [markdown]
# ## Combining data

# %%
tr_nb_list<-sample(100, 20, replace = FALSE)

for (i in 1:20){
    tr <- tree_list[[tr_nb_list[i]]]
    temp <- read.table(lst_files_TS_TE[[i]], sep ="\t", header = TRUE)
    temp_tabl <- cbind(tabl, temp)
    temp_phy <- as.data.frame(cbind(SpeciesAge::calculateTipAges(tr)[,1],lapply(SpeciesAge::calculateTipAges(tr)[,2], meanAge, lambda = mean(unlist(tab[7,-1])), mu = mean(unlist(tab[8,-1])), rho = 38/44)))
    temp_phy2 <- temp_phy[! temp_phy[,1] %in% temp_tabl[,1],2]
    temp_neonto <- as.data.frame(cbind(rep(0,length(temp_phy2)), ((nrow(temp_tabl)+1):(nrow(temp_tabl)+length(temp_phy2))), temp_phy2, rep(0,length(temp_phy2))))
    colnames(temp_neonto) <- colnames(temp)
    data_TS_TE <- rbind(temp, temp_neonto)
    data_TS_TE$clade <- unlist(data_TS_TE$clade)
    data_TS_TE$species <- unlist(data_TS_TE$species)
    data_TS_TE$ts <- unlist(data_TS_TE$ts)
    data_TS_TE$te <- unlist(data_TS_TE$te)
    # write.table(data_TS_TE, paste("PyRate/Test/Occ_sp_Orecto_combined", i, "_G_KEEP_BDS_se_est.txt", sep =""), sep = "\t", col.names = TRUE, row.names = FALSE, quote = FALSE)
    
    
    
}

# %%
temp_tab <- temp_tab[-1, ]

# %%
temp_tab
# Out:
#     scientificName                       184.5 183.5 182.5 181.5 180.5 179.5
# 3   Adnetoscyllium angloparisensis       NaN   NaN   NaN   NaN   NaN   NaN
# 4   Almascyllium cheikheliasi            NaN   NaN   NaN   NaN   NaN   NaN
# 5   Annea altucuspis                     NaN   NaN   NaN   NaN   NaN   NaN
# 6   Annea carinata                       NaN   NaN   NaN   NaN   NaN   NaN
# 7   Annea maubeugei                      NaN   NaN     2     0     0     2
# 8   Annea myriacuspis                    NaN   NaN   NaN   NaN   NaN   NaN
# 9   Brachaelurid (gen. nov.) roklumensis NaN   NaN   NaN   NaN   NaN   NaN
# 10  Cantioscyllium alhaulfi              NaN   NaN   NaN   NaN   NaN   NaN
# 11  Cantioscyllium bighornensis          NaN   NaN   NaN   NaN   NaN   NaN
# 12  Cantioscyllium brachyplicatum        NaN   NaN   NaN   NaN   NaN   NaN
# 13  Cantioscyllium clementsi             NaN   NaN   NaN   NaN   NaN   NaN
# ...

# %%
temp_phy$V1 <- gsub("_", " ", temp_phy$V1)

# %%
temp_tab
# Out:
#     scientificName                       184.5 183.5 182.5 181.5 180.5 179.5
# 3   Adnetoscyllium angloparisensis       NaN   NaN   NaN   NaN   NaN   NaN
# 4   Almascyllium cheikheliasi            NaN   NaN   NaN   NaN   NaN   NaN
# 5   Annea altucuspis                     NaN   NaN   NaN   NaN   NaN   NaN
# 6   Annea carinata                       NaN   NaN   NaN   NaN   NaN   NaN
# 7   Annea maubeugei                      NaN   NaN     2     0     0     2
# 8   Annea myriacuspis                    NaN   NaN   NaN   NaN   NaN   NaN
# 9   Brachaelurid (gen. nov.) roklumensis NaN   NaN   NaN   NaN   NaN   NaN
# 10  Cantioscyllium alhaulfi              NaN   NaN   NaN   NaN   NaN   NaN
# 11  Cantioscyllium bighornensis          NaN   NaN   NaN   NaN   NaN   NaN
# 12  Cantioscyllium brachyplicatum        NaN   NaN   NaN   NaN   NaN   NaN
# 13  Cantioscyllium clementsi             NaN   NaN   NaN   NaN   NaN   NaN
# ...

# %%
temp_phy[,1] %in% temp_tab[,1]
# Out:
#  [1] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE  TRUE
# [13] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
# [25] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE  TRUE
# [37] FALSE FALSE

# %%
temp_phy
# Out:
#    V1                                V2
# 1  Brachaelurus colcloughi           6.724713
# 2  Brachaelurus waddi                6.724713
# 3  Chiloscyllium arabicum            3.626028
# 4  Chiloscyllium burmensis           3.626028
# 5  Chiloscyllium griseum             0.8858404
# 6  Chiloscyllium hasseltii           0.8858404
# 7  Chiloscyllium indicum             6.723463
# 8  Chiloscyllium plagiosum           6.723463
# 9  Chiloscyllium punctatum           6.724721
# 10 Cirrhoscyllium formosanum         6.724728
# 11 Eucrossorhinus dasypogon          6.721384
# 12 Ginglymostoma cirratum            4.27678
# 13 Ginglymostoma unami               4.27678
# 14 Hemiscyllium galei                5.376739
# 15 Hemiscyllium hallstromi           4.231966
# 16 Hemiscyllium halmahera            5.683715
# 17 Hemiscyllium henryi               5.376739
# 18 Hemiscyllium michaeli             3.544089
# 19 Hemiscyllium ocellatum            5.840748
# ...

# %% [markdown]
# ## Combining data (DES)

# %%
temp_tab <- read.table("../DES/Analysis_ML/sp_1/sp_1_DES_20.txt", sep ="\t")
colnames(temp_tab) <- as.character(temp_tab[1,])
temp_tab <- temp_tab[-1, ]

# %%
phy$tip.label
# Out:
#  [1] "Parascyllium_collare"              "Parascyllium_ferrugineum"
#  [3] "Cirrhoscyllium_formosanum"         "Hemiscyllium_ocellatum"
#  [5] "Hemiscyllium_strahani"             "Hemiscyllium_trispeculare"
#  [7] "Hemiscyllium_michaeli"             "Hemiscyllium_hallstromi"
#  [9] "Hemiscyllium_galei"                "Hemiscyllium_henryi"
# [11] "Hemiscyllium_halmahera"            "Chiloscyllium_griseum"
# [13] "Chiloscyllium_hasseltii"           "Chiloscyllium_arabicum"
# [15] "Chiloscyllium_burmensis"           "Chiloscyllium_plagiosum"
# [17] "Chiloscyllium_indicum"             "Chiloscyllium_punctatum"
# [19] "Stegostoma_fasciatum"              "Pseudoginglymostoma_brevicaudatum"
# [21] "Rhincodon_typus"                   "Ginglymostoma_cirratum"
# [23] "Ginglymostoma_unami"               "Nebrius_ferrugineus"
# [25] "Eucrossorhinus_dasypogon"          "Orectolobus_floridus"
# [27] "Sutorectus_tentaculatus"           "Orectolobus_halei"
# ...

# %%
temp_tab[3,4]
# Out:
# [1] NaN

# %%
phy <- tree_list[[1]]
