# %% [markdown]
# # Make data for DES

# %% [markdown]
# ## Loading packages

# %%
library("ape")
library("SpeciesAge")
# Out:
# Le chargement a nécessité le package : diversitree
#
# Le chargement a nécessité le package : TreeSim
#
# Le chargement a nécessité le package : geiger
#
# Le chargement a nécessité le package : phytools
#
# Le chargement a nécessité le package : maps
#
# Le chargement a nécessité le package : picante
#
# Le chargement a nécessité le package : vegan
#
# Le chargement a nécessité le package : permute
#
# Le chargement a nécessité le package : lattice
#
# This is vegan 2.6-8
#
#
# Attachement du package : ‘vegan’
#
#
# L'objet suivant est masqué depuis ‘package:phytools’:
#
#     scores
#
#
# Le chargement a nécessité le package : nlme

# %% [markdown]
# ## Loading data

# %%
table_occ <- read.table("../../../Data/Occurences/Occurences_extinct_Orectolobiformes.tsv", sep ="\t", header = TRUE)

# %%
status_gen <- read.table("../../../Data/Occurences/Data_Occ_gen_Orecto_TaxonList.txt", sep ="\t", header = TRUE)
status_sp <- read.table("../../../Data/Occurences/Data_Occ_sp_Orecto_TaxonList.txt", sep ="\t", header = TRUE)

# %% [markdown]
# ## Cleaning data

# %%
table_species <- table_occ[-grep("sp[.]", table_occ$Species),]

# %% [markdown]
# ## DES

# %% [markdown]
# ### Create function for DES

# %%
make_table_DES <- function(table_fossil, prefix, col){ 
    temp_table <- cbind(table_fossil[,col], table_fossil$Earliest.Age, table_fossil$Latest.Age, table_fossil$Paleobiogeography)
    for(i in 1:nrow(table_fossil)){
        if(table_fossil$Paleobiogeography[i] != "Tethys"){
            temp_table[i,4] <- "Outside_Tethys"
        }
    }
    temp_table <- as.data.frame(temp_table)
    colnames(temp_table) <- c("scientificName", "earliestAge", "latestAge", "higherGeography")
write.table(temp_table[as.numeric(temp_table$latestAge) < 100.5,], paste(prefix, "_Tethys.txt", sep = ""), col.names = TRUE, row.names = FALSE, quote = FALSE, sep = "\t")
}

# %% [markdown]
# ## PyRate (region)

# %%
make_table_PyRate <- function(table_fossil, prefix, prefix2, col, status){ 
    status <- status[status$Status == "extant",]
    temp_table <- cbind(gsub(" ", "_", table_fossil[,col]), rep("extinct", nrow(table_fossil)), table_fossil$Latest.Age, table_fossil$Earliest.Age, table_fossil$Paleobiogeography)
    for(i in 1:nrow(temp_table)){
        if(temp_table[i,1] %in% status$Species){
            temp_table[i,2] <- "extant"
        }
    }
    
    table_outside <- temp_table[temp_table[,5] != "Tethys",]
    table_tethys <- temp_table[temp_table[,5] == "Tethys",]
    table_outside <- as.data.frame(table_outside)
    table_outside <- table_outside[,-5]
    colnames(table_outside) <- c("Species", "Status", "MinT", "MaxT")    
    table_tethys <- as.data.frame(table_tethys)
    table_tethys <- table_tethys[,-5]
    colnames(table_tethys) <- c("Species", "Status", "MinT", "MaxT")
    
write.table(table_outside[as.numeric(table_outside$MinT) < 100.5,], paste(prefix, "outside_Tethys/Data_Occ_", prefix2, "_Orecto_outside_Tethys.tsv", sep = ""), col.names = TRUE, row.names = FALSE, quote = FALSE, sep = "\t")
write.table(table_tethys[as.numeric(table_tethys$MinT) < 100.5,], paste(prefix, "Tethys/Data_Occ_", prefix2, "_Orecto_Tethys.tsv", sep = ""), col.names = TRUE, row.names = FALSE, quote = FALSE, sep = "\t")
}

# %%
table_species
# Out:
#     Order            Family                        Genus
# 1   Orectolobiformes Hemiscylliidae                Acanthoscyllium
# 2   Orectolobiformes Hemiscylliidae                Adnetoscyllium
# 3   Orectolobiformes Hemiscylliidae                Adnetoscyllium
# 4   Orectolobiformes Hemiscylliidae                Adnetoscyllium
# 5   Orectolobiformes Hemiscylliidae                Adnetoscyllium
# 6   Orectolobiformes Hemiscylliidae                Adnetoscyllium
# 7   Orectolobiformes Hemiscylliidae                Adnetoscyllium
# 8   Orectolobiformes Hemiscylliidae                Adnetoscyllium
# 9   Orectolobiformes Hemiscylliidae                Adnetoscyllium
# 10  Orectolobiformes Hemiscylliidae                Adnetoscyllium
# 13  Orectolobiformes Hemiscylliidae                Almascyllium
# 15  Orectolobiformes Orectolobiformes incert. fam. Annea
# 16  Orectolobiformes Orectolobiformes incert. fam. Annea
# 17  Orectolobiformes Orectolobiformes incert. fam. Annea
# 18  Orectolobiformes Orectolobiformes incert. fam. Annea
# 19  Orectolobiformes Orectolobiformes incert. fam. Annea
# 20  Orectolobiformes Orectolobiformes incert. fam. Annea
# 21  Orectolobiformes Orectolobiformes incert. fam. Annea
# 22  Orectolobiformes Orectolobiformes incert. fam. Annea
# 26  Orectolobiformes Brachaeluridae                Brachaelurid (gen. nov.)
# 30  Orectolobiformes Ginglymostomatidae            Cantioscyllium
# 31  Orectolobiformes Ginglymostomatidae            Cantioscyllium
# 32  Orectolobiformes Ginglymostomatidae            Cantioscyllium
# 33  Orectolobiformes Ginglymostomatidae            Cantioscyllium
# 34  Orectolobiformes Ginglymostomatidae            Cantioscyllium
# 35  Orectolobiformes Ginglymostomatidae            Cantioscyllium
# 36  Orectolobiformes Ginglymostomatidae            Cantioscyllium
# 37  Orectolobiformes Ginglymostomatidae            Cantioscyllium
# 38  Orectolobiformes Ginglymostomatidae            Cantioscyllium
# 39  Orectolobiformes Ginglymostomatidae            Cantioscyllium
# ⋮   ⋮                ⋮                             ⋮
# 652 Orectolobiformes Ginglymostomatidae            Pseudoginglymostoma
# 653 Orectolobiformes Ginglymostomatidae            Pseudoginglymostoma
# 654 Orectolobiformes Ginglymostomatidae            Pseudoginglymostoma
# 657 Orectolobiformes Hemiscylliidae                Pseudospinax
# 658 Orectolobiformes Hemiscylliidae                Pseudospinax
# 659 Orectolobiformes Hemiscylliidae                Pseudospinax
# 660 Orectolobiformes Hemiscylliidae                Pseudospinax
# 661 Orectolobiformes Hemiscylliidae                Pseudospinax
# 662 Orectolobiformes Hemiscylliidae                Pseudospinax
# 681 Rhincodon typus
# 682 Rhincodon typus
# 683 Rhincodon typus
# 684 Squatiscyllium casieri
# 685 Squatiscyllium nigeriensis
# 686 Squatiscyllium nigeriensis
# 687 Squatiscyllium nigeriensis
# 688 Squatiscyllium nigeriensis
# 695 Stegostoma tethysiensis
#     Reported.as                             Earliest.Age Latest.Age
# 1                                            85.8         83.601
# 2                                            83.6         80.601
# 3                                            83.6         80.601
# 4                                            83.6         80.601
# 5                                            83.6         80.601
# 6                                            83.6         80.601
# 7                                            83.6         80.601
# 8                                            85.8         83.601
# 9                                            85.8         83.601
# 10                                           86.3         83.601
# 13                                           85.8         83.601
# 15                                          163.1        157.301
# 16  Orectolobiformes inc. fam., gen. et sp. 166.1        163.101
# 17                                          166.1        163.101
# 18                                          170.3        168.301
# 19                                          174.2        170.301
# 20                                          183.7        174.201
# 21                                          183.7        174.201
# 22  Akaimia myriacuspis                     166.1        163.101
# 26                                          130.8        126.301
# 30                                          130.8        126.301
# 31                                           76.4         72.101
# 32                                           86.3         83.601
# 33                                           89.8         86.301
# 34                                          100.5         96.201
# 35                                           83.6         72.101
# 36                                          100.5         93.901
# 37                                          100.5         89.801
# 38                                          100.5         93.901
# 39                                           89.8         86.301
# ⋮   ⋮                                       ⋮            ⋮
# 652                                          72.100       70.101
# 653                                          70.100       66.001
# 654                                          72.100       66.001
# 657                                         100.500       96.201
# 658                                         100.500       96.201
# 659                                         107.600      100.501
# 660                                         107.600      100.501
# 661                                         107.600      100.501
# 662                                         107.600      100.501
# 663 Protospinax heterodon                   110.200      100.501
# 664                                         100.500       93.901
# 666                                          72.100       66.001
# 667                                          70.100       66.001
# 668                                          70.100       66.001
# 669                                          70.600       66.001
# 670 Squatirhina americana                    70.600       66.001
# 671                                          70.600       66.001
# 672                                          83.600       72.101
# 673                                          83.600       72.101
# 674 Galagadon nordquistae                    70.100       66.001
# 675                                          20.440       15.971
# 681                                          28.100       23.031
# 682                                           5.333        2.589
# 683 Rhincodon typus                          41.300       15.971
# 684                                          56.000       47.801
# 685 Squatina sp.                             59.200       47.801
# 686                                          59.200       56.001
# 687                                          59.200       56.001
# 688                                          59.200       56.001
# 695                                          41.000       38.001
#     Stratigraphic.age                 Country        Paleobiogeography_all
# 1   Santonian (Upper)                 Lebanon        Tethys
# 2   Campanian (Lower)                 France         Tethys
# 3   Campanian (Lower)                 France         Tethys
# 4   Campanian (Lower)                 United Kingdom Tethys
# 5   Campanian (Lower)                 United Kingdom Tethys
# 6   Campanian (Lower)                 United Kingdom Tethys
# 7   Campanian (Lower)                 United Kingdom Tethys
# 8   Santonian (Upper)                 France         Tethys
# 9   Santonian (Upper)                 United Kingdom Tethys
# 10  Santonian                         United Kingdom Tethys
# 13  Santonian (Upper)                 Lebanon        Tethys
# 15  Oxfordian                         Poland         Tethys
# 16  Callovian                         Germany        Tethys
# 21  Delsate & Weis (2010)
# 22  Srdic et al. (2016)
# 26  Thies (1981)
# 30  Kriwet (1999b)
# 31  Case (1987)
# 32  Kirkland et al. (2013)
# 33  Kirkland et al. (2013)
# 34  Kriwet et al. (2009)
# 35  Case et al. (2019)
# 36  Pfeil (2013, 2021)
# 37  Welton & Farish (1993)
# 38  Welton & Farish (1993)
# 39  Hamm & Cicimurri (2011); Welton & Farish (1993); Hamm (2009)
# ⋮   ⋮
# 652 Noubhani & Cappetta (1997)
# 653 Noubhani & Cappetta (1997)
# 654 Noubhani & Cappetta (1997)
# 657 Guinot et al. (2012a-b; 2013)
# 658 Underwood & Mitchell (1999)
# 659 Underwood & Mitchell (1999)
# 660 Underwood & Mitchell (1999)
# 661 Underwood & Mitchell (1999)
# 662 Underwood & Mitchell (1999)
# 663 Ward (2010)
# 664 Müller & Diedrich (1991)
# 666 Langston Jr (1975)
# 667 Cook et al. (2014)
# 668 Estes (1969); Cook et al. (2014); Kelly (2014)
# 669 Carpenter (1979)
# 670 Estes (1964); Breithaupt (1982)
# 671 Wroblewski et al. (2004)
# 672 Kirkland et al. (2013)
# 673 Rowe et al. (1992)
# 674 Gates et al. (2019)
# 675 Mendiola (1996)
# 681 Gonzalez-Barba & Thies (2000)
# 682 Lira-Beltrán et al. (2020)
# 683 Maisch et al. (2021)
# 684 Arambourg (1952d) See also Noubhani & Cappetta (1997)
# 685 Rana et al. (2005)
# 686 Rajkumari & Prasad (2020)
# 687 Cappetta (1972)
# 688 White (1943b)
# 695 Adnet et al. (2020)

# %%
table_fossil, prefix, prefix2, col, status)
table_species, "../../BDS/Results/Biogeo/Species/", "sp", 4, status_sp)

status <- status[status$Status == "extant",]
    temp_table <- cbind(gsub(" ", "_", table_fossil[,col]), rep("extinct", nrow(table_fossil)), table_fossil$Latest.Age, table_fossil$Earliest.Age, table_fossil$Paleobiogeography)
    for(i in 1:nrow(temp_table)){
        if(temp_table[i,1] %in% status$Species){
            temp_table[i,2] <- "extant"
        }
    }
    
    table_outside <- temp_table[temp_table[,5] != "Tethys",]
    table_tethys <- temp_table[temp_table[,5] == "Tethys",]
    table_outside <- as.data.frame(table_outside)
    table_outside <- table_outside[,-5]
    colnames(table_outside) <- c("Species", "Status", "MinT", "MaxT")    
    table_tethys <- as.data.frame(table_tethys)
    table_tethys <- table_tethys[,-5]
    colnames(table_tethys) <- c("Species", "Status", "MinT", "MaxT")

# %% [markdown]
# ### Execute function for species dataset

# %%
make_table_DES(table_species, "../Input/Sp", 4)

# %%
make_table_PyRate(table_species, "../../BDS/Results/Biogeo/Species/", "sp", 4, status_sp)

# %% [markdown]
# ### Execute function for genus dataset

# %%
make_table_DES(table_occ, "../Input/Gen", 3)

# %%
make_table_PyRate(table_occ, "../../BDS/Results/Biogeo/Genus/", "gen", 3, status_gen)
