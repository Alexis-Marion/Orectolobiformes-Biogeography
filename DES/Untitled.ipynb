# %%
library("SpeciesAge")
# Out:
# Le chargement a nécessité le package : ape
#
# Le chargement a nécessité le package : diversitree
#
# Le chargement a nécessité le package : TreeSim
#
# Le chargement a nécessité le package : geiger
#
# Le chargement a nécessité le package : phytools
#
# Le chargement a nécessité le package : maps
#
# Le chargement a nécessité le package : picante
#
# Le chargement a nécessité le package : vegan
#
# Le chargement a nécessité le package : permute
#
# Le chargement a nécessité le package : lattice
#
# This is vegan 2.6-8
#
#
# Attachement du package : ‘vegan’
#
#
# L'objet suivant est masqué depuis ‘package:phytools’:
#
#     scores
#
#
# Le chargement a nécessité le package : nlme

# %%
tree<-read.nexus("../Data_orectolobiformes/Orectolobiformes_extant_tree.nex")

# %%
SpeciesAge::estimateBD(tree, epsilon = 0.75, 38/44)
# Out:
#     lambda         mu
# 0.03896770 0.02922578

# %%
SpeciesAge::calculateTipAges(tree)
# Out:
#    tip                               age
# 1  Brachaelurus_colcloughi           45.5334456
# 2  Brachaelurus_waddi                45.5334456
# 3  Chiloscyllium_arabicum             8.1463792
# 4  Chiloscyllium_burmensis            8.1463792
# 5  Chiloscyllium_griseum              0.4889799
# 6  Chiloscyllium_hasseltii            0.4889799
# 7  Chiloscyllium_indicum             35.0822461
# 8  Chiloscyllium_plagiosum           35.0822461
# 9  Chiloscyllium_punctatum           53.7976313
# 10 Cirrhoscyllium_formosanum         79.8053890
# 11 Eucrossorhinus_dasypogon          30.8730405
# 12 Ginglymostoma_cirratum             4.9896761
# 13 Ginglymostoma_unami                4.9896761
# 14 Hemiscyllium_galei                 6.1184439
# 15 Hemiscyllium_hallstromi            7.4254367
# 16 Hemiscyllium_halmahera             9.4093474
# 17 Hemiscyllium_henryi                6.1184439
# 18 Hemiscyllium_michaeli              5.3440050
# 19 Hemiscyllium_ocellatum            12.1396691
# ...

# %%
SpeciesAge::

# %%
SpeciesAge::integrateRate
# Out:
# function (lambda, mu, t1, t2, rho)
# {
#     2 * (mu * t2 - log(lambda * rho - (lambda * (rho - 1) + mu) *
#         exp((mu - lambda) * t2))) - 2 * (mu * t1 - log(lambda *
#         rho - (lambda * (rho - 1) + mu) * exp((mu - lambda) *
#         t1)))
# }
# <bytecode: 0x55bb67a54da0>
# <environment: namespace:SpeciesAge>

# %%
SpeciesAge::meanAge(45.5334456, 0.0389677011153378, 0.0292257758365033, 38/44)
# Out:
# [1] 27.45033
